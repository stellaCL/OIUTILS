# %%
# %pylab notebook
from oiutils import oifits, oimodels, tellcorr, dpfit
import os
from astropy.io import fits
import ipywidgets as widgets

directory = '/Users/amerand/DATA/Science/NOVA/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # list all the reduced files

# %%
files = os.listdir(directory)
files = filter(lambda x: x.endswith('vis.fits'), files) # reduced

files = sorted([os.path.join(directory, f) for f in files])
print(files)
# Out:
# ['/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-02T23:41:34.642_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-02T23:52:43.670_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T00:26:04.754_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T00:37:19.783_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T02:31:04.619_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T02:42:13.647_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T02:59:16.689_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T03:10:31.718_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:13:42.853_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:24:51.881_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:35:45.909_singlecalvis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:46:54.938_singlecal
# ...

# %% [markdown]
# # telluric correction for calibrators

# %%
# -- narrow HeI, Br gamma and CO bandheads (for K giants calibrators)
avoid = [(2.056, 2.060), (2.165, 2.168), (2.293, 2.300), (2.322, 2.328), (2.352, 2.357), (2.382, 2.389), (2.415, 2.420)]

cals = [files[3], files[4], files[-2], files[-1]]
print(cals)

#-- calibrator for first epoch
for i,c in enumerate(cals):
    tellcorr.gravity(c, quiet=(i==len(cals)-1), save=True, wlmin=1.95, wlmax=2.45, MR=False, avoid=avoid)
# Out:
# ['/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T00:37:19.783_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T02:31:04.619_singlescivis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:35:45.909_singlecalvis.fits', '/Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:46:54.938_singlecalvis.fits']
# <img src="data:image/png;base64,..." width="1000">
# WL: (1742,)
# > fit only spectrum shape, not tellurics
# > fit all but spectral resolution (kernel)
# > fit everything
# [dpfit] 4 FITTED parameters: ['kern_max', 'kern_min', 'kernp_max', 'kernp_min']
# [dpfit] using scipy.optimize.leastsq
# [dpfit] Mon Feb 17 11:59:35 2020     1CHI2: 4.1209e+08|pwv=-1.41e+00|pow=1.44e+00|kern_min=2.80e-04|kern_max=3.40e-04|kernp_min=1.70e+00|kernp_max=1.70e+00
# [dpfit] Both actual and predicted relative reductions in the sum of squares
#   are at most 0.000010
# [dpfit] number of function call: 46
# [dpfit] time per function call: 46.82 (ms)
# ...

# %%
scis = [files[0], files[1], files[-4], files[-3]]

# -- very broad HeI, Br gamma and CO bandheads (Nova, early epoch)
avoid = [(2.054, 2.062), (2.163, 2.169), (2.293, 2.300), (2.322, 2.328), (2.352, 2.357), (2.382, 2.389), (2.415, 2.420)]

# -- broad HeI, Br gamma and CO bandheads (Nova, late epoch)
avoid = [(2.03, 2.09), (2.14, 2.20), (2.293, 2.300), (2.322, 2.328), (2.352, 2.357), (2.382, 2.389), (2.415, 2.420)]

tellcorr.gravity(scis[0], quiet=False, save=True, wlmin=1.95, wlmax=2.45, MR=False, avoid=avoid)
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">
# WL: (1742,)
# > fit only spectrum shape, not tellurics
# > fit all but spectral resolution (kernel)
# /Users/amerand/Library/Python/3.8/lib/python/site-packages/oiutils-0.1.dev0-py3.8.egg/oiutils/dpfit.py:471: RuntimeWarning: invalid value encountered in true_divide
#   cor = cov/cor
# > fit everything
# [dpfit] 32 FITTED parameters: ['dl0', 'dl1', 'dl2', 'dl3', 'kern_max', 'kern_min', 'kernp_max', 'kernp_min', 'p_2.09913', 'p_2.11905', 'p_2.12825', 'p_2.1691', 'pow', 'pwv', 'yS0', 'yS1', 'yS14', 'yS15', 'yS16', 'yS17', 'yS18', 'yS19', 'yS2', 'yS20', 'yS22', 'yS24', 'yS26', 'yS28', 'yS29', 'yS7', 'yS8', 'yS9']
# [dpfit] using scipy.optimize.leastsq
# [dpfit] Wed Mar 11 14:07:31 2020     1CHI2: 2.0639e+06|pwv=-2.47e-01|pow=1.22e+00|kern_min=2.80e-04|kern_max=3.40e-04|kernp_min=1.70e+00|kernp_max=1.70e+00
# ...

# %%
lines = {'HeI':[(2.0581, 2.11274, 2.11267, 2.11258, 2.161), 'c', 'dashed'],
         #'HeII':((2.1885), 'c', 'dotted'),
         'MgII':((2.137, 2.143, ), '0.5', 'dashed'),
         'MgI':((2.10655, 2.10666), '0.5', 'dotted'),
         # -- Br gamma and Pfund
         'HI':[(2.1661, #2.360, 2.367, 2.374, 2.383, 2.392, 2.404, 2.416, 2.431, 2.449
               ), 'b', 'dashed'],
         #'H2':[(2.122), 'b', 'dotted'],
         #'NaI':[(2.208, 2.208969), 'y', 'dashed'],
         #'NIII':[(2.1155, 2.247, 2.251), (0,1,0.5), 'dashed'],
         #'FeII':((2.089, 2.145, 2.241, 2.368), 'g', 'dashed'),
         r'$^{12}$C$^{16}$O HB':(np.array([2.2935, 2.3227, 2.3535, 2.3829, 2.4142]), 'r', 'dashed'),
         #r'$^{13}$C$^{16}$O HB':([2.3448, 2.3739, 2.4037, 2.4341, ], 'r', 'dotted'), #2.4971
         #'AlI':((2.109884,2.116958),(0.2,0.5,0.8), 'dotted'),
         #'MgI':((2.121393,2.146472,2.386573),'r'),
         #'ScI':((2.20581,2.20714),'m'),
         #'SiII':((2.200),'g'),
         #'CaI':((1.99318, 2.261410, 2.263110, 2.265741),'g', 'dotted'), #1.89282, 1.94508, 1.98702, 
             }
# == use calibrator Telluric spectrum to correct nova

def Fback(wl, T):
    hcKb = 6.62607015e-34*3e8/1.380649e-23
    return 1/wl**5*1/(np.exp(hcKb/(wl*1e-6)/T) - 1)

if False:
    # -- early epoch
    nova1 = oifits.loadOI(files[0], insname='GRAVITY_SC')
    nova2 = oifits.loadOI(files[1], insname='GRAVITY_SC')
    cal1 = oifits.loadOI(files[3], insname='GRAVITY_SC')
    cal2 = oifits.loadOI(files[4], insname='GRAVITY_SC')
    
    title = 'V3890 Sgr 2019-09-02'
    filename = '/Users/amerand/Desktop/Plots/V3890Sgr/K_spectrum_early.pdf'
else:
    # -- late epoch
    nova1 = oifits.loadOI(files[-4], insname='GRAVITY_SC')
    nova2 = oifits.loadOI(files[-3], insname='GRAVITY_SC')
    cal2 = oifits.loadOI(files[-2], insname='GRAVITY_SC')
    cal1 = oifits.loadOI(files[-1], insname='GRAVITY_SC')

    title = 'V3890 Sgr 2019-09-24'
    filename = '/Users/amerand/Desktop/Plots/V3890Sgr/K_spectrum_late.pdf'

data, dmask = [], []
ref, rmask = [], []

for k in nova1['OI_FLUX'].keys():
    data.append(nova1['OI_FLUX'][k]['FLUX'][0])
    dmask.append(~nova1['OI_FLUX'][k]['FLAG'][0])
    data.append(nova2['OI_FLUX'][k]['FLUX'][0])
    dmask.append(~nova2['OI_FLUX'][k]['FLAG'][0])
    
    ref.append(cal1['OI_FLUX'][k]['FLUX'][0])
    rmask.append(~cal1['OI_FLUX'][k]['FLAG'][0])
    ref.append(cal2['OI_FLUX'][k]['FLUX'][0])
    rmask.append(~cal2['OI_FLUX'][k]['FLAG'][0])
    
data = np.array(data)
dmask = np.array(dmask)
ref = np.array(ref)
rmask = np.array(rmask)

wd = (data.std(axis=0)/data.mean(axis=0)<0.5)
ww = np.abs(nova1['WL'][wd]-2.25)<0.05

plt.figure(11, figsize=(10,4.5))
plt.clf()

ax1 = plt.subplot(211)
ax2 = plt.subplot(212, sharex=ax1)

ax1.step(nova1['WL'], data.mean(axis=0)[wd][ww].mean()*cal1['TELLURICS'], color='y', alpha=0.5, linewidth=1, label='tellurics')
ax1.step(nova1['WL'][wd], data.mean(axis=0)[wd], color='k', alpha=0.2, linewidth=1, label='raw')
ax1.step(nova1['WL'][wd], data.mean(axis=0)[wd]/cal1['TELLURICS'][wd], color='k', marker='', linewidth=1, label='corrected')

export = [nova1['WL'], data.mean(axis=0), cal1['TELLURICS'], data.mean(axis=0)/cal1['TELLURICS']]
export[1][~wd] = np.nan
export[3][~wd] = np.nan
np.savetxt(title.replace(' ', '_')+'_spectrum.txt', np.transpose(export), fmt=['%.4f', '%.5e', '%.4f', '%.5e'], header='WL(um) raw tellurics corrected')

F = np.ones(len(nova1['WL']))*(data/cal1['TELLURICS']).mean(axis=0)[wd][nova1['WL'][wd]<2.025].mean() + 2e14*Fback(nova1['WL'], 295)
print(Fback(nova1['WL'], 293).max())
#ax1.plot(nova1['WL'], F, '-b')

wr = (ref.std(axis=0)/ref.mean(axis=0)<0.5)
ww = np.abs(cal1['WL'][wr]-2.25)<0.05
ax2.step(cal1['WL'], ref.mean(axis=0)[wr][ww].mean()*cal1['TELLURICS'], color='y', alpha=0.5, linewidth=1, label='tellurics')
ax2.step(cal1['WL'][wr], ref.mean(axis=0)[wr], color='k', alpha=0.2, linewidth=1, label='raw')
ax2.step(cal1['WL'][wr], ref.mean(axis=0)[wr]/cal1['TELLURICS'][wr], color='k', marker='', linewidth=1, label='corrected')

F = np.ones(len(nova1['WL']))*(ref/cal1['TELLURICS']).mean(axis=0)[wd][nova1['WL'][wd]<2.025].mean() + 2e14*Fback(nova1['WL'], 295)
print(Fback(nova1['WL'], 293).max())
#ax2.plot(nova1['WL'], F, '-b')

ax1.legend(fontsize=6)

ax2.set_xlabel('wavelength (microns)')
ax1.set_ylabel('flux (arb. units)')
ax1.set_title(title)

plt.tight_layout()
#plt.ylim(plt.ylim()[0], np.percentile(data.mean(axis=0)[w]/cal1['TELLURICS'][w], 99))
ax1.set_ylim(0, 1.2*np.percentile(data.mean(axis=0)[wd]/cal1['TELLURICS'][wd], 99))
ax2.set_ylim(0, 1.2*np.percentile(ref.mean(axis=0)[wr]/cal1['TELLURICS'][wr], 99))

for k in list(lines.keys()):
    ax1.vlines(lines[k][0], ax1.get_ylim()[0], ax1.get_ylim()[1], color=lines[k][1],
            linestyle=lines[k][2], label=k, alpha=0.3, linewidth=1)
ax1.legend(fontsize=6, ncol=4)

#plt.savefig(filename)
# Out:
# **** /Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:13:42.853_singlescivis.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_FLUX {'A0', 'D0', 'B2', 'C1'} (1, 1742)
# OI_T3 {'C1D0A0', 'C1B2A0', 'C1D0B2', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:24:51.881_singlescivis.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_FLUX {'A0', 'D0', 'B2', 'C1'} (1, 1742)
# OI_T3 {'C1D0A0', 'C1B2A0', 'C1D0B2', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:35:45.909_singlecalvis.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# ...

# %% [markdown]
# # Modeling Visibility: first epoch

# %%
# -- get tellurics from calibrators
cal0 = oifits.loadOI(os.path.join(directory, 'GRAVI.2019-09-03T00:37:19.783_singlescivis.fits'), insname='GRAVITY_SC')
tell0 = cal0['TELLURICS']

data0 = [oifits.loadOI(os.path.join(directory, 'calibrated/GRAVI.2019-09-02T23:41:34.642_singlescivis_singlesciviscalibrated.fits'), insname='GRAVITY_SC', medfilt=5, tellurics=tell0),
        oifits.loadOI(os.path.join(directory, 'calibrated/GRAVI.2019-09-02T23:52:43.670_singlescivis_singlesciviscalibrated.fits'), insname='GRAVITY_SC', medfilt=5, tellurics=tell0)]
data=None
# Out:
# **** /Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-03T00:37:19.783_singlescivis.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_FLUX {'A0', 'D0', 'B2', 'C1'} (1, 1742)
# TELLURICS (1742,)
# OI_T3 {'C1D0A0', 'C1B2A0', 'C1D0B2', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/calibrated/GRAVI.2019-09-02T23:41:34.642_singlescivis_singlesciviscalibrated.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1D0', 'B2A0', 'C1A0', 'C1B2', 'D0B2'} (1, 1742)
# OI_FLUX {'A0', 'D0', 'B2', 'C1'} (1, 1742)
# OI_T3 {'C1D0A0', 'C1B2A0', 'C1D0B2', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/calibrated/GRAVI.2019-09-02T23:52:43.670_singlescivis_singlesciviscalibrated.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# ...

# %%
ntabs = 2*(len(data0)+2)
outs0 = [widgets.Output() for i in range(ntabs)]
tab0 = widgets.Tab(children=outs0)
display(tab0)

# %%
from importlib import reload
reload(oimodels)
reload(oifits)
reload(dpfit)

#display(tab0)

line = 'HeI'
#line = 'Brg'

fit = {# -- observable to fit
       'obs':['|V|', 'DPHI', 'NFLUX', 'T3PHI'], 
       # -- where to fit list of tuples (lambda_min, lambda_max)
       #'wl ranges': [(2.06-0.065, 2.06+0.06)],
       # -- minimum error: override the errors in data file
       'min error': {'NFLUX':0.05, '|V|':0.04, 'DPHI':2.0, 'T3PHI':4.0},
       # -- maximum error: ignore data which are too noisy
       #'max error': {'NFLUX':0.5, '|V|':0.2, 'DPHI':5.0, 'T3PHI':10.0, 'V2':0.05},
       # -- spectral resolution, in pixels (default is no convolution)
       #'spec res pix': 1.4
}

# -- model:
param = {'center,f':               1 ,
        'center,ud':              0.1 ,
        }

if line == 'HeI':
    wl0 = 2.06
    # -- where to fit list of tuples (lambda_min, lambda_max)
    fit['wl ranges'] = [(wl0-0.065, wl0+0.06)]
    it = 0
    ifig = 1
    ngauss = 5 # number of "nodes" around central object
    center_has_line = False
    nodes_on_ring = False
    doNotFit = ['center,f', #'center,ud'
               ]
    fitOnly = []
    
elif line == 'Brg':
    wl0 = 2.167
    # -- where to fit list of tuples (lambda_min, lambda_max)
    fit['wl ranges'] = [(wl0-0.065, wl0+0.22)]
    it = 4
    ifig = 11
    ngauss = 0
    center_has_line = True
    nodes_on_ring = False
    doNotFit = ['center,f', 'center,ud']
    param.update({#'wide,ud':5, 
                  'wide,f0':0.5, 'wide,f2':0.1})
    fitOnly = []#'wide,f0', 'wide,f2',]
else:
    assert False, 'unknown spectral line "'+str(line)+'", must be in ["HeI", "Brg"]'

for d in data0:
    d['fit'] = fit
    
if center_has_line:
    param.update({'center,line_1_f': 0.641,
                  'center,line_1_lorentzian': 2.39, 
                  'center,line_1_wl0':      wl0, 
                 })
    
fitOnly.extend( list(filter(lambda x: ',line_' in x, param.keys())))

if nodes_on_ring:
    Xell = lambda r, i, pa, phi: np.cos(pa*np.pi/180)*r*np.cos(phi*np.pi/180)*np.cos(i) + np.sin(pa*np.pi/180)*r*np.sin(phi*np.pi/180)
    Yell = lambda r, i, pa, phi: -np.sin(pa*np.pi/180)*r*np.cos(phi*np.pi/180)*np.cos(i) +  np.cos(pa*np.pi/180)*r*np.sin(phi*np.pi/180)

if ngauss==1:
    dwl = [0]
else:
    dwl = np.linspace(-0.02, 0.02, ngauss)
    
for i in range(ngauss):
    param.update({'%d,x'%i:np.random.randn(), '%d,y'%i:np.random.randn(),
                  '%d,ud'%i:0.2,
                  '%d,f'%i:0.,
                  '%d,line_1_f'%i: 0.1,
                  '%d,line_1_gaussian'%i: 2.0, # +/- 0.12
                  '%d,line_1_wl0'%i:      wl0 + dwl[i], # +/- 0.000042
                 })
    if nodes_on_ring:
        param.update({'%d,x'%i:(Xell, ('_r', '_i', '_pa', '%d,phi'%i)), 
                      '%d,y'%i:(Yell, ('_r', '_i', '_pa', '%d,phi'%i)), 
                      '%d,phi'%i:360*np.random.rand()})

    doNotFit.extend([# '%d,ud'%i, # comment to fit size of nodes
                     '%d,f'%i])
    fitOnly.extend(['%d,line_1_f'%i,'%d,line_1_gaussian'%i, '%d,line_1_wl0'%i])

if nodes_on_ring:
    param.update({'_r':3, '_i':20.0, '_pa':45.0})
    
# ================= FIT =======================
if True:
    with outs0[it]:
        tab0.selected_index = it
        tab0.children[it].clear_output()
        tab0.set_title(it, line+': fitting spectrum')
        it += 1
        # -- fit Only Spectrum
        for d in data0:
            d['fit']['obs'] = ['NFLUX']
        z = oimodels.residualsOI(data0, param)*0.0
        fit = dpfit.leastsqFit(oimodels.residualsOI, data0, param, z, verbose=2, maxfev=2000, fitOnly=fitOnly, ftol=1e-4,)
        param = fit['best']
    with outs0[it]:
        tab0.selected_index = it
        tab0.set_title(it, line+': fitting everything')
        tab0.children[it].clear_output()
        it+=1
        ## -- fit position of the nodes
        for d in data0:
            d['fit']['obs'] = ['DPHI', 'NFLUX', '|V|']
        z = oimodels.residualsOI(data0, param)*0.0
        fit = dpfit.leastsqFit(oimodels.residualsOI, data0, param, z, verbose=2, maxfev=2000, doNotFit=doNotFit, ftol=1e-4,)
        param = fit['best']
else:
    param= {'0,f':               0.0 ,
        '0,fwhm':            1.57, # +/- 0.20
        '0,line_1_f':        0.3705, # +/- 0.0061
        '0,line_1_gaussian': 16.00, # +/- 0.37
        '0,line_1_wl0':      2.03949, # +/- 0.00024
        '0,x':               0.960, # +/- 0.033
        '0,y':               0.209, # +/- 0.029
        '1,f':               0.0 ,
        '1,fwhm':            1.80, # +/- 0.43
        '1,line_1_f':        0.326, # +/- 0.016
        '1,line_1_gaussian': 5.02, # +/- 0.20
        '1,line_1_wl0':      2.045805, # +/- 0.000073
        '1,x':               -0.89, # +/- 0.10
        '1,y':               -0.371, # +/- 0.074
        '2,f':               0.0 ,
        '2,fwhm':            3.45, # +/- 0.11
        '2,line_1_f':        0.674, # +/- 0.033
        '2,line_1_gaussian': 15.42, # +/- 0.78
        '2,line_1_wl0':      2.05909, # +/- 0.00019
        '2,x':               -0.199, # +/- 0.045
        '2,y':               -0.523, # +/- 0.039
        '3,f':               0.0 ,
        '3,fwhm':            0.27, # +/- 3.07
        '3,line_1_f':        0.526, # +/- 0.031
        '3,line_1_gaussian': 5.27, # +/- 0.20
        '3,line_1_wl0':      2.059789, # +/- 0.000052
        '3,x':               0.350, # +/- 0.076
        '3,y':               0.402, # +/- 0.077
        '4,f':               0.0 ,
        '4,fwhm':            4.38, # +/- 0.17
        '4,line_1_f':        0.300, # +/- 0.023
        '4,line_1_gaussian': 8.95, # +/- 0.50
        '4,line_1_wl0':      2.07111, # +/- 0.00019
        '4,x':               0.93, # +/- 0.14
        '4,y':               0.032, # +/- 0.081
        '5,f':               0.0 ,
        '5,fwhm':            1.78, # +/- 0.33
        '5,line_1_f':        0.2671, # +/- 0.0084
        '5,line_1_gaussian': 8.66, # +/- 0.31
        '5,line_1_wl0':      2.07963, # +/- 0.00016
        '5,x':               -1.020, # +/- 0.066
        '5,y':               -0.476, # +/- 0.049
        'center,f':          1 ,
        'center,ud':         0.1 ,
        }

# ================ PLOT ==========================
for d in data0:
    d['fit']['obs'] = ['|V|', 'DPHI', 'NFLUX']
# -- show result (only first file)
for i, d in enumerate(data0):
    with outs0[it]:
        tab0.selected_index = it
        tab0.children[it].clear_output()
        if i==len(data0)-1:
            tab0.set_title(it, line+': data#%d and model'%i)
            it+=1
            oimodels.showOI(data0[i], param, fig=ifig, showIm=True, fov=8.0, pix=0.05, imPow=.1, imWl0=np.linspace(wl0-0.015, wl0+0.015, 2), plotWidth=12)
        else:
            tab0.set_title(it, line+': data#%d'%i)
            it+=1
            oimodels.showOI(data0[i], param, fig=ifig, plotWidth=12)            
        ifig+=1

# %% [markdown]
# # modeling visibility: second epoch

# %%
reload(oifits)
cal1 = oifits.loadOI(os.path.join(directory, 'GRAVI.2019-09-24T02:35:45.909_singlecalvis.fits'), insname='GRAVITY_SC')
tell1 = cal1['TELLURICS']
data1 = [oifits.loadOI(os.path.join(directory, 'calibrated/GRAVI.2019-09-24T02:13:42.853_singlescivis_singlesciviscalibrated.fits'), insname='GRAVITY_SC', medfilt=0, tellurics=tell1),
         oifits.loadOI(os.path.join(directory, 'calibrated/GRAVI.2019-09-24T02:24:51.881_singlescivis_singlesciviscalibrated.fits'), insname='GRAVITY_SC', medfilt=0, tellurics=tell1)]
# Out:
# **** /Users/amerand/DATA/Science/NOVA/GRAVI.2019-09-24T02:35:45.909_singlecalvis.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1B2', 'D0B2', 'B2A0', 'C1A0', 'C1D0'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1B2', 'D0B2', 'B2A0', 'C1A0', 'C1D0'} (1, 1742)
# OI_FLUX {'B2', 'D0', 'A0', 'C1'} (1, 1742)
# TELLURICS (1742,)
# OI_T3 {'C1D0B2', 'C1D0A0', 'C1B2A0', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/calibrated/GRAVI.2019-09-24T02:13:42.853_singlescivis_singlesciviscalibrated.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# OI_VIS {'D0A0', 'C1B2', 'D0B2', 'B2A0', 'C1A0', 'C1D0'} (1, 1742)
# OI_VIS2 {'D0A0', 'C1B2', 'D0B2', 'B2A0', 'C1A0', 'C1D0'} (1, 1742)
# OI_FLUX {'B2', 'D0', 'A0', 'C1'} (1, 1742)
# OI_T3 {'C1D0B2', 'C1D0A0', 'C1B2A0', 'D0B2A0'} (1, 1742)
# **** /Users/amerand/DATA/Science/NOVA/calibrated/GRAVI.2019-09-24T02:24:51.881_singlescivis_singlesciviscalibrated.fits insname= GRAVITY_SC **********
# WAVELENGTH: 1742
# ...

# %%
from importlib import reload
reload(oimodels)
reload(oifits)
reload(dpfit)

fit = {# -- observable to fit
       'obs':['|V|', 'DPHI', 'NFLUX', 'T3PHI'], 
       # -- where to fit list of tuples (lambda_min, lambda_max)
       #'wl ranges': [(2.06-0.065, 2.06+0.06)],
        'wl ranges': [(2.167-0.03, 2.167+0.03)],
       # -- minimum error: override the errors in data file
       'min error': {'NFLUX':0.05, '|V|':0.04, 'DPHI':2.0, 'T3PHI':4.0},
       # -- maximum error: ignore data which are too noisy
       #'max error': {'NFLUX':0.5, '|V|':0.2, 'DPHI':5.0, 'T3PHI':10.0, 'V2':0.05},
       # -- spectral resolution, in pixels (default is no convolution)
       #'spec res pix': 1.4
}
for d in data1:
    d['fit'] = fit
    
# -- model:
param = {'center,f':               1 ,
        'center,line_1_f':        0.641, # +/- 0.011
        'center,line_1_gaussian': 5.39, # +/- 0.10
        'center,line_1_wl0':      2.1667, # +/- 0.000043
        'center,ud':0.1,
        'resolved,f':.2,
#         'resolved,ud':10,
#         'resolved,line_1_f':        0.641, # +/- 0.011
#         'resolved,line_1_gaussian': 5.39, # +/- 0.10
#         'resolved,line_1_wl0':      2.1667, # +/- 0.000043
        }

doNotFit = ['center,f', 'center,ud',
           ]

fitOnly = list(filter(lambda x: ',line_' in x, param.keys()))

# ================= FIT =======================
if True:
    ntabs = len(data1)+2
    outs1 = [widgets.Output() for i in range(ntabs)]
    #tab1 = widgets.Tab(children=outs1)
    tab1 = widgets.Tab(children=outs1)
    
    display(tab1)
    i = 0
    with outs1[i]:
        tab1.selected_index = i
        tab1.set_title(i, 'fitting spectrum only')
        # -- fit Only Spectrum
        for d in data1:
            d['fit']['obs'] = ['NFLUX']
        z = oimodels.residualsOI(data1, param)*0.0
        fit = dpfit.leastsqFit(oimodels.residualsOI, data1, param, z, verbose=2, maxfev=2000, fitOnly=fitOnly, ftol=1e-4,)
        param = fit['best']
    i = 1
    with outs1[i]:
        tab1.selected_index = i
        tab1.set_title(i, 'fitting everything')
        ## -- fit position of the nodes
        for d in data1:
            d['fit']['obs'] = ['DPHI', 'NFLUX', '|V|']
        z = oimodels.residualsOI(data1, param)*0.0
        fit = dpfit.leastsqFit(oimodels.residualsOI, data1, param, z, verbose=2, maxfev=2000, doNotFit=doNotFit, ftol=1e-4,)
        param = fit['best']
else:
    ntabs = len(data1)
    outs1 = [widgets.Output() for i in range(ntabs)]
    tab1 = widgets.Tab(children=outs1)
    display(tab1)
    param = {'center,f':               1 ,
            'center,line_1_f':        0.727, # +/- 0.025
            'center,line_1_gaussian': 2.203, # +/- 0.088
            'center,line_1_wl0':      2.166010, # +/- 0.000041
            'center,ud':              0.1 ,
            'resolved,f':             0.3518, # +/- 0.0041
            'resolved,ud':            47.97, # +/- 0.70
            }

# ================ PLOT ==========================
for d in data1:
    d['fit']['obs'] = ['|V|', 'DPHI', 'NFLUX', 'T3PHI']
# -- show result (only first file)

for i, d in enumerate(data1):
    with outs1[i+2]:
        tab1.selected_index = i+2
        if i==len(data1)-1:
            tab1.set_title(i+2, 'data#%d and model'%i)
            oimodels.showOI(data1[i], param, fig=i+1, showIm=True, fov=50.0, pix=0.5, imPow=.1, imWl0=[2.0, 2.166], plotWidth=12)
        else:
            tab1.set_title(i+2, 'data#%d'%i)
            oimodels.showOI(data1[i], param, fig=i+1, plotWidth=12)  
# i+=1
# with outs[i]:
#     tab.selected_index = i
#     tab.set_title(i, 'u, v')
#     oimodels.showUV(data1, fig=i+1)
